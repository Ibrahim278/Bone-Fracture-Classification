# %%
# %run data_loader.py
# Out:
# 2023-04-12 15:33:41.378907: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 0

# %%
# %run mura.py
# Out:
# Network configuration:
# batch_size 8
# nb_epoch 52
# depth 22
# nb_dense_block 4
# nb_filter 16
# growth_rate 12
# dropout_rate 0.2
# learning_rate 0.001
# weight_decay 0.0001
# plot_architecture False
# 0
# 0
# /Users/ibrahimirfan/anaconda3/lib/python3.10/site-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/ibrahimirfan/anaconda3/lib/python3.10/site-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in divide
#   ret = ret.dtype.type(ret / rcount)
# /Users/ibrahimirfan/anaconda3/lib/python3.10/site-packages/numpy/core/_methods.py:265: RuntimeWarning: Degrees of freedom <= 0 for slice
#   ret = _var(a, axis=axis, dtype=dtype, out=out, ddof=ddof,
# /Users/ibrahimirfan/anaconda3/lib/python3.10/site-packages/numpy/core/_methods.py:223: RuntimeWarning: invalid value encountered in divide
#   arrmean = um.true_divide(arrmean, div, out=arrmean, casting='unsafe',
# ...

# %%
# %run model_test.py
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/Downloads/Bone-Fracture-Detection---MURA-master/model_test.py:22
#      16 from keras.models import model_from_json
#      18 im_size = 320
# ---> 22 model = densenet.DenseNet(nb_classes=1, img_dim=(320,320,1), depth=22, nb_dense_block=4, growth_rate=12, nb_filter=16, dropout_rate=0.2, weight_decay=1E-4)
#      24 model.load_weights('./save_models/MURA_modle@epochs52.h5')
#      26 X_valid_path, Y_valid = data_loader.load_path(root_path = './valid/XR_HUMERUS', size = im_size)
#
# File ~/Downloads/Bone-Fracture-Detection---MURA-master/densenet.py:131, in DenseNet(nb_classes, img_dim, depth, nb_dense_block, growth_rate, nb_filter, dropout_rate, weight_decay)
#     113 def DenseNet(nb_classes, img_dim, depth, nb_dense_block, growth_rate, nb_filter, dropout_rate=None, weight_decay=1E-4):
#     114     """
# ...

# %%
# %run plot_results_train_acc.py
